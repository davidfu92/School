# %%
import numpy
a = numpy.array([-2,-1,0,1,2,3])
b = numpy.array([2,0,2,0,2,6])
c = a * b
d = numpy.sum(c)
print(d)
# Out:
# 18

# %%
a = numpy.random.rand(6, 7)
b = numpy.random.rand(7, 8)
c = numpy.dot(a, b)
print(a)
print(b)
print(c)
print(c.shape[1])
# Out:
# [[0.87867387 0.37313483 0.98962371 0.20976442 0.29254474 0.52928216
#   0.59825689]
#  [0.51379676 0.15325233 0.98475555 0.11240349 0.32826875 0.90403043
#   0.97056066]
#  [0.04392679 0.98642697 0.47602437 0.68696435 0.37485007 0.15402416
#   0.98111099]
#  [0.62700426 0.99386454 0.5300648  0.86765446 0.48171836 0.98854884
#   0.7645087 ]
#  [0.16652398 0.93290984 0.58385945 0.4229295  0.35267412 0.38941129
#   0.66800867]
#  [0.83771655 0.24099056 0.06540788 0.76286179 0.2022034  0.45918025
#   0.28686157]]
# [[5.20114237e-02 8.95088892e-01 4.78095515e-02 5.17552957e-01
#   6.86335632e-01 9.68117210e-01 9.47798324e-01 5.42889659e-01]
#  [6.02952651e-01 9.59262509e-01 7.47854857e-01 9.42904780e-01
#   1.69530945e-01 7.92607345e-01 5.68656766e-01 2.28011139e-01]
#  [5.31438525e-01 3.20126467e-01 5.04846869e-01 8.84133427e-01
#   2.06771202e-04 8.85304972e-01 9.38795360e-01 5.49885319e-02]
#  [6.17952228e-01 3.63443691e-01 4.15187219e-01 1.96436016e-02
# ...
